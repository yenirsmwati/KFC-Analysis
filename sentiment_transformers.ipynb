# %%
import pandas as pd
import re

# %%
filepath1 = r"/content/review_kfc_jember.csv"
df_kfc= pd.read_csv(filepath1,encoding='ISO-8859-1')

# %%
filepath2 = r"/content/review_mcd_jember.csv"
df_mcd= pd.read_csv(filepath2,encoding='ISO-8859-1')

# %%
filepath3 = r"/content/review_burgerking_jember.csv"
df_burgerking= pd.read_csv(filepath3,encoding='ISO-8859-1')

# %%
df_kfc.head(2)
# Out:
#    page                           name  \
# 0     1  faridaismailbunga rahmatillah
# 1     1                  Faisol Abrori
#
#                                                 link  \
# 0  https://www.google.com/maps/contrib/1166978675...
# 1  https://www.google.com/maps/contrib/1081565429...
#
#                                            thumbnail  rating           date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjX7B...       4  2 minggu lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjWvK...       4   7 bulan lalu
#
#                                              snippet  \
# 0  Tempatx luas banget malah, parkir d belakang j...
# 1  untuk tempatnya sih oke, luas, trus table nya ...
#
#                                               images local_guide fastfood
# 0  ['https://lh3.googleusercontent.com/geougc-cs/...        True      KFC
# 1  ['https://lh3.googleusercontent.com/geougc-cs/...        True      KFC

# %%
df_mcd.head(2)
# Out:
#    page                    name  \
# 0     1  Ryan Ravi Is Syahputra
# 1     1            Siti Fawaida
#
#                                                 link  \
# 0  https://www.google.com/maps/contrib/1069228858...
# 1  https://www.google.com/maps/contrib/1164249739...
#
#                                            thumbnail  rating          date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjXDJ...       5  5 tahun lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjWuB...       5  setahun lalu
#
#                                              snippet  \
# 0  McDonald's Jember\nTempat terfavorit saya yang...
# 1  Ini sih take away + dine in wkwk\nApalagi yg m...
#
#                                               images local_guide    fastfood
# 0  ['https://lh3.googleusercontent.com/geougc-cs/...        True  McDonald's
# 1  ['https://lh3.googleusercontent.com/geougc-cs/...        True  McDonald's

# %%
df_burgerking.head(2)
# Out:
#    page             name                                               link  \
# 0     1  Sujatyoko Utomo  https://www.google.com/maps/contrib/1062201926...
# 1     1    Another Ricky  https://www.google.com/maps/contrib/1012235979...
#
#                                            thumbnail  rating          date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjUaI...       5  5 bulan lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjVXH...       4  7 bulan lalu
#
#                                              snippet  \
# 0  Suasananya enak, tempatnya bersih, lokasinya s...
# 1  Rasa burgernya sangat iconic dan enak, kentang...
#
#                                               images local_guide     fastfood
# 0  ['https://lh3.googleusercontent.com/geougc-cs/...        True  Burger King
# 1  ['https://lh3.googleusercontent.com/geougc-cs/...        True  Burger King

# %%
data_kfc = df_kfc[["rating","snippet","fastfood", "date"]]
data_kfc.head()
# Out:
#    rating                                            snippet fastfood  \
# 0       4  Tempatx luas banget malah, parkir d belakang j...      KFC
# 1       4  untuk tempatnya sih oke, luas, trus table nya ...      KFC
# 2       4  Tempatnya nyaman, parkiran aman dijaga oleh ka...      KFC
# 3       4  Pelayanan cepat, kalau cuaca cerah bisa makan ...      KFC
# 4       5  Ayamnya enak crispy n sering ada promo, minuma...      KFC
#
#             date
# 0  2 minggu lalu
# 1   7 bulan lalu
# 2   9 bulan lalu
# 3    3 hari lalu
# 4  11 bulan lalu

# %%
data_mcd = df_mcd[["rating","snippet","fastfood", "date"]]
data_mcd.head()
# Out:
#    rating                                            snippet    fastfood  \
# 0       5  McDonald's Jember\nTempat terfavorit saya yang...  McDonald's
# 1       5  Ini sih take away + dine in wkwk\nApalagi yg m...  McDonald's
# 2       5  McD punya tempat spesial di hati. Disini serin...  McDonald's
# 3       4  Cocok untuk sahur dan berbuka di bulan Ramadha...  McDonald's
# 4       5  Untuk rice bowl harga overprice dg porsi segit...  McDonald's
#
#            date
# 0  5 tahun lalu
# 1  setahun lalu
# 2  setahun lalu
# 3  5 tahun lalu
# 4  setahun lalu

# %%
data_burger = df_burgerking[["rating","snippet","fastfood", "date"]]
data_burger.head()
# Out:
#    rating                                            snippet     fastfood  \
# 0       5  Suasananya enak, tempatnya bersih, lokasinya s...  Burger King
# 1       4  Rasa burgernya sangat iconic dan enak, kentang...  Burger King
# 2       5  Managernya ramah, sangat sigap membantu pengun...  Burger King
# 3       5  Pelayanan Baik. Untuk Tempat Nyaman cocok untu...  Burger King
# 4       5  selalu menjadi tujuan tiap ke roxy square\nsej...  Burger King
#
#             date
# 0   5 bulan lalu
# 1   7 bulan lalu
# 2   2 bulan lalu
# 3  3 minggu lalu
# 4   6 bulan lalu

# %%
## Analisis Rating

avg_kfc = data_kfc["rating"].mean()
avg_mcd = data_mcd["rating"].mean()
avg_burger = data_burger["rating"].mean()

avg_rating_df = pd.DataFrame({
    'Nama Brand' : ['KFC', 'McDonald\'s', 'Burger King'],
    'Rata-Rata Rating' : [avg_kfc, avg_mcd, avg_burger]
})

print(avg_rating_df)
# Out:
#     Nama Brand  Rata-Rata Rating
# 0          KFC          4.102513
# 1   McDonald's          4.370110
# 2  Burger King          4.565962

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rating_count_kfc = data_kfc['rating'].value_counts().sort_index()
rating_count_mcd = data_mcd['rating'].value_counts().sort_index()
rating_count_burger = data_burger['rating'].value_counts().sort_index()

# %%
plt.figure(figsize=(10,6))
plt.bar(rating_count_kfc.index - 0.2, rating_count_kfc.values, width=0.2, label='KFC', color='orange')
plt.bar(rating_count_mcd.index, rating_count_mcd.values, width=0.2, label='McD', color='blue')
plt.bar(rating_count_burger.index + 0.2, rating_count_burger.values, width=0.2, label='Burger King', color='green')

plt.xlabel("Rating")
plt.ylabel("Jumlah Ulasan")
plt.title("Distribusi Rating Pelanggan")
plt.xticks([1, 2, 3, 4, 5])  # Pastikan sumbu x hanya menampilkan rating dari 1-5
plt.legend()
plt.show()

# %%
data_kfc['date'].unique()
# Out:
# array(['2 minggu lalu', '7 bulan lalu', '9 bulan lalu', '3 hari lalu',
#        '11 bulan lalu', '2 tahun lalu', 'setahun lalu', '5 tahun lalu',
#        '10 bulan lalu', '6 tahun lalu', '2 bulan lalu', '5 hari lalu',
#        '3 tahun lalu', '7 tahun lalu', 'sebulan lalu', '3 bulan lalu',
#        '4 tahun lalu', '5 bulan lalu', '8 tahun lalu', '9 tahun lalu',
#        '8 bulan lalu'], dtype=object)

# %%
data_mcd['date'].unique()
# Out:
# array(['5 tahun lalu', 'setahun lalu', '3 tahun lalu', '4 tahun lalu',
#        '2 tahun lalu'], dtype=object)

# %%
data_burger['date'].unique()
# Out:
# array(['5 bulan lalu', '7 bulan lalu', '2 bulan lalu', '3 minggu lalu',
#        '6 bulan lalu', 'seminggu lalu', '4 minggu lalu', 'setahun lalu',
#        'sebulan lalu', '3 bulan lalu', '6 tahun lalu', '3 tahun lalu',
#        '4 tahun lalu', '5 tahun lalu', '4 bulan lalu', '2 tahun lalu',
#        '1 hari lalu', '10 bulan lalu', '11 bulan lalu', '2 minggu lalu',
#        '9 bulan lalu', '8 bulan lalu', '2 hari lalu'], dtype=object)

# %%
data_kfc['date'] = data_kfc['date'].replace({'setahun lalu': '1 tahun lalu','sebulan lalu':'1 bulan lalu', 'seminggu lalu': '1 minggu lalu'})
data_mcd['date'] = data_mcd['date'].replace({'setahun lalu': '1 tahun lalu', 'sebulan lalu':'1 bulan lalu','seminggu lalu': '1 minggu lalu'})
data_burger['date'] = data_burger['date'].replace({'setahun lalu': '1 tahun lalu', 'sebulan lalu':'1 bulan lalu','seminggu lalu': '1 minggu lalu'})
# Out:
# <ipython-input-22-1439c582e696>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kfc['date'] = data_kfc['date'].replace({'setahun lalu': '1 tahun lalu','sebulan lalu':'1 bulan lalu', 'seminggu lalu': '1 minggu lalu'})
# <ipython-input-22-1439c582e696>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_mcd['date'] = data_mcd['date'].replace({'setahun lalu': '1 tahun lalu', 'sebulan lalu':'1 bulan lalu','seminggu lalu': '1 minggu lalu'})
# <ipython-input-22-1439c582e696>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_burger['date'] = data_burger['date'].replace({'setahun lalu': '1 tahun lalu', 'sebulan lalu':'1 bulan lalu','seminggu lalu': '1 minggu lalu'})

# %%
data_kfc['date'].unique()
# Out:
# array(['2 minggu lalu', '7 bulan lalu', '9 bulan lalu', '3 hari lalu',
#        '11 bulan lalu', '2 tahun lalu', '1 tahun lalu', '5 tahun lalu',
#        '10 bulan lalu', '6 tahun lalu', '2 bulan lalu', '5 hari lalu',
#        '3 tahun lalu', '7 tahun lalu', '1 bulan lalu', '3 bulan lalu',
#        '4 tahun lalu', '5 bulan lalu', '8 tahun lalu', '9 tahun lalu',
#        '8 bulan lalu'], dtype=object)

# %%
data_mcd['date'].unique()
# Out:
# array(['5 tahun lalu', '1 tahun lalu', '3 tahun lalu', '4 tahun lalu',
#        '2 tahun lalu'], dtype=object)

# %%
data_burger['date'].unique()
# Out:
# array(['5 bulan lalu', '7 bulan lalu', '2 bulan lalu', '3 minggu lalu',
#        '6 bulan lalu', '1 minggu lalu', '4 minggu lalu', '1 tahun lalu',
#        '1 bulan lalu', '3 bulan lalu', '6 tahun lalu', '3 tahun lalu',
#        '4 tahun lalu', '5 tahun lalu', '4 bulan lalu', '2 tahun lalu',
#        '1 hari lalu', '10 bulan lalu', '11 bulan lalu', '2 minggu lalu',
#        '9 bulan lalu', '8 bulan lalu', '2 hari lalu'], dtype=object)

# %%
from datetime import datetime, timedelta

# Fungsi untuk mengonversi string seperti "1 bulan lalu" menjadi tanggal aktual
def convert_to_datetime(date_str):
    # Waktu saat ini
    now = datetime.now()

    # Pisahkan string menjadi jumlah dan satuan waktu
    parts = date_str.split()
    if len(parts) != 3:
        raise ValueError(f"Format tanggal tidak valid: {date_str}")

    jumlah = int(parts[0])  # Ambil angka (misalnya, 1, 2, 5)
    satuan = parts[1]       # Ambil satuan waktu (misalnya, "hari", "minggu", "bulan", "tahun")

    # Hitung tanggal berdasarkan satuan waktu
    if satuan == "hari":
        return now - timedelta(days=jumlah)
    elif satuan == "minggu":
        return now - timedelta(weeks=jumlah)
    elif satuan == "bulan":
        return now - timedelta(days=30 * jumlah)  # Asumsi 1 bulan = 30 hari
    elif satuan == "tahun":
        return now - timedelta(days=365 * jumlah)  # Asumsi 1 tahun = 365 hari
    else:
        raise ValueError(f"Satuan waktu tidak dikenali: {satuan}")

data_kfc = pd.DataFrame(data_kfc)
data_mcd = pd.DataFrame(data_mcd)
data_burger = pd.DataFrame(data_burger)

# Apply function to column 'date' dan simpan hasilnya di kolom yang sama
data_kfc['date_new'] = data_kfc['date'].apply(convert_to_datetime)
data_mcd['date_new'] = data_mcd['date'].apply(convert_to_datetime)
data_burger['date_new'] = data_burger['date'].apply(convert_to_datetime)

# %%
data_kfc.head()
# Out:
#    rating                                            snippet fastfood  \
# 0       4  Tempatx luas banget malah, parkir d belakang j...      KFC
# 1       4  untuk tempatnya sih oke, luas, trus table nya ...      KFC
# 2       4  Tempatnya nyaman, parkiran aman dijaga oleh ka...      KFC
# 3       4  Pelayanan cepat, kalau cuaca cerah bisa makan ...      KFC
# 4       5  Ayamnya enak crispy n sering ada promo, minuma...      KFC
#
#             date                   date_new
# 0  2 minggu lalu 2025-01-21 14:03:11.696541
# 1   7 bulan lalu 2024-07-09 14:03:11.696563
# 2   9 bulan lalu 2024-05-10 14:03:11.696568
# 3    3 hari lalu 2025-02-01 14:03:11.696572
# 4  11 bulan lalu 2024-03-11 14:03:11.696575

# %%
data_mcd.head()
# Out:
#    rating                                            snippet    fastfood  \
# 0       5  McDonald's Jember\nTempat terfavorit saya yang...  McDonald's
# 1       5  Ini sih take away + dine in wkwk\nApalagi yg m...  McDonald's
# 2       5  McD punya tempat spesial di hati. Disini serin...  McDonald's
# 3       4  Cocok untuk sahur dan berbuka di bulan Ramadha...  McDonald's
# 4       5  Untuk rice bowl harga overprice dg porsi segit...  McDonald's
#
#            date                   date_new
# 0  5 tahun lalu 2020-02-06 14:03:11.710481
# 1  1 tahun lalu 2024-02-05 14:03:11.710499
# 2  1 tahun lalu 2024-02-05 14:03:11.710502
# 3  5 tahun lalu 2020-02-06 14:03:11.710504
# 4  1 tahun lalu 2024-02-05 14:03:11.710507

# %%
data_burger.head()
# Out:
#    rating                                            snippet     fastfood  \
# 0       5  Suasananya enak, tempatnya bersih, lokasinya s...  Burger King
# 1       4  Rasa burgernya sangat iconic dan enak, kentang...  Burger King
# 2       5  Managernya ramah, sangat sigap membantu pengun...  Burger King
# 3       5  Pelayanan Baik. Untuk Tempat Nyaman cocok untu...  Burger King
# 4       5  selalu menjadi tujuan tiap ke roxy square\nsej...  Burger King
#
#             date                   date_new
# 0   5 bulan lalu 2024-09-07 14:03:11.715313
# 1   7 bulan lalu 2024-07-09 14:03:11.715325
# 2   2 bulan lalu 2024-12-06 14:03:11.715328
# 3  3 minggu lalu 2025-01-14 14:03:11.715331
# 4   6 bulan lalu 2024-08-08 14:03:11.715346

# %%
# Analisis waktu

# Menghitung selisih antara tanggal saat ini dan tanggal ulasan
data_kfc['date_diff'] = pd.to_datetime('today') - data_kfc['date_new']
data_kfc['days_ago'] = data_kfc['date_diff'].dt.days

# %%
data_kfc.head(2)
# Out:
#    rating                                            snippet fastfood  \
# 0       4  Tempatx luas banget malah, parkir d belakang j...      KFC
# 1       4  untuk tempatnya sih oke, luas, trus table nya ...      KFC
#
#             date                   date_new                date_diff  days_ago
# 0  2 minggu lalu 2025-01-21 14:03:11.696541  14 days 00:00:18.810416        14
# 1   7 bulan lalu 2024-07-09 14:03:11.696563 210 days 00:00:18.810394       210

# %%
data_mcd['date_diff'] = pd.to_datetime('today') - data_mcd['date_new']
data_mcd['days_ago'] = data_mcd['date_diff'].dt.days

# %%
data_mcd.head(2)
# Out:
#    rating                                            snippet    fastfood  \
# 0       5  McDonald's Jember\nTempat terfavorit saya yang...  McDonald's
# 1       5  Ini sih take away + dine in wkwk\nApalagi yg m...  McDonald's
#
#            date                   date_new                 date_diff  days_ago
# 0  5 tahun lalu 2020-02-06 14:03:11.710481 1825 days 00:00:26.370742      1825
# 1  1 tahun lalu 2024-02-05 14:03:11.710499  365 days 00:00:26.370724       365

# %%
data_burger['date_diff'] = pd.to_datetime('today') - data_burger['date_new']
data_burger['days_ago'] = data_burger['date_diff'].dt.days
data_burger.head(2)
# Out:
#    rating                                            snippet     fastfood  \
# 0       5  Suasananya enak, tempatnya bersih, lokasinya s...  Burger King
# 1       4  Rasa burgernya sangat iconic dan enak, kentang...  Burger King
#
#            date                   date_new                date_diff  days_ago
# 0  5 bulan lalu 2024-09-07 14:03:11.715313 150 days 00:00:30.343583       150
# 1  7 bulan lalu 2024-07-09 14:03:11.715325 210 days 00:00:30.343571       210

# %%
# Mengelompokkan berdasarkan bulan dan menghitung jumlah ulasan per bulan
data_kfc['month'] = data_kfc['date_new'].dt.to_period('M')
reviews_per_month_kfc = data_kfc.groupby('month').size()

# Menampilkan jumlah ulasan per bulan
reviews_per_month_kfc.head(10)
# Out:
# month
# 2016-02      5
# 2017-02     21
# 2018-02    133
# 2019-02    228
# 2020-02    237
# 2021-02    115
# 2022-02     99
# 2023-02     81
# 2024-02     48
# 2024-03      1
# Freq: M, dtype: int64

# %%
# Mengelompokkan berdasarkan bulan dan menghitung jumlah ulasan per bulan
data_mcd['month'] = data_mcd['date_new'].dt.to_period('M')
reviews_per_month_mcd = data_mcd.groupby('month').size()

# Menampilkan jumlah ulasan per bulan
reviews_per_month_mcd.head()
# Out:
# month
# 2020-02    309
# 2021-02    207
# 2022-02    239
# 2023-02    141
# 2024-02    101
# Freq: M, dtype: int64

# %%
# Mengelompokkan berdasarkan bulan dan menghitung jumlah ulasan per bulan
data_burger['month'] = data_burger['date_new'].dt.to_period('M')
reviews_per_month_burger = data_burger.groupby('month').size()

# Menampilkan jumlah ulasan per bulan
reviews_per_month_burger.head()
# Out:
# month
# 2019-02     28
# 2020-02    249
# 2021-02    113
# 2022-02    115
# 2023-02     36
# Freq: M, dtype: int64

# %%
# Menghitung rata-rata rating per bulan
avg_rating_per_month_kfc = data_kfc.groupby('month')['rating'].mean()
avg_rating_per_month_mcd = data_mcd.groupby('month')['rating'].mean()
avg_rating_per_month_burger = data_burger.groupby('month')['rating'].mean()

# Menampilkan rata-rata rating per bulan
print(avg_rating_per_month_kfc.head())
print(avg_rating_per_month_mcd.head())
print(avg_rating_per_month_burger.head())
# Out:
# month
# 2016-02    3.800000
# 2017-02    3.190476
# 2018-02    3.796992
# 2019-02    4.192982
# 2020-02    4.189873
# Freq: M, Name: rating, dtype: float64
# month
# 2020-02    4.414239
# 2021-02    4.415459
# 2022-02    4.372385
# 2023-02    4.340426
# 2024-02    4.178218
# Freq: M, Name: rating, dtype: float64
# month
# 2019-02    3.821429
# 2020-02    4.401606
# 2021-02    4.495575
# 2022-02    4.460870
# 2023-02    3.805556
# Freq: M, Name: rating, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot jumlah ulasan per bulan
reviews_per_month_kfc.plot(kind='line', label='KFC')
reviews_per_month_mcd.plot(kind='line', label='McDonald\'s')
reviews_per_month_burger.plot(kind='line', label='Burger King')
plt.title('Jumlah Review per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Ulasan')
plt.legend()  # Menambahkan legend
plt.show()

# Plot rata-rata rating per bulan
avg_rating_per_month_kfc.plot(kind='line', label='KFC')
avg_rating_per_month_mcd.plot(kind='line', label='McDonald\'s')
avg_rating_per_month_burger.plot(kind='line', label='Burger King')
plt.title('Rata-rata Rating per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata Rating')
plt.legend()  # Menambahkan legend
plt.show()

# %%
# Analisis Sentiment menggunakan Transformers

import pandas as pd
from transformers import pipeline

# %%
# Muat model dan tokenizer
pretrained_name = "ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa"
nlp = pipeline("sentiment-analysis", model=pretrained_name, tokenizer=pretrained_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/476k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
def get_sentiment(text):
    result = nlp(text)
    return result[0]['label']

# %%
data_kfc['sentiment'] = data_kfc['snippet'].apply(get_sentiment)
data_mcd['sentiment'] = data_mcd['snippet'].apply(get_sentiment)

# %%
data_kfc.head()
# Out:
#    rating                                            snippet fastfood  \
# 0       4  Tempatx luas banget malah, parkir d belakang j...      KFC
# 1       4  untuk tempatnya sih oke, luas, trus table nya ...      KFC
# 2       4  Tempatnya nyaman, parkiran aman dijaga oleh ka...      KFC
# 3       4  Pelayanan cepat, kalau cuaca cerah bisa makan ...      KFC
# 4       5  Ayamnya enak crispy n sering ada promo, minuma...      KFC
#
#             date                   date_new                date_diff  \
# 0  2 minggu lalu 2025-01-21 14:03:11.696541  14 days 00:00:18.810416
# 1   7 bulan lalu 2024-07-09 14:03:11.696563 210 days 00:00:18.810394
# 2   9 bulan lalu 2024-05-10 14:03:11.696568 270 days 00:00:18.810389
# 3    3 hari lalu 2025-02-01 14:03:11.696572   3 days 00:00:18.810385
# 4  11 bulan lalu 2024-03-11 14:03:11.696575 330 days 00:00:18.810382
#
#    days_ago    month sentiment
# 0        14  2025-01  Positive
# 1       210  2024-07  Positive
# 2       270  2024-05  Positive
# 3         3  2025-02  Positive
# 4       330  2024-03  Positive

# %%
data_mcd.head()
# Out:
#    rating                                            snippet    fastfood  \
# 0       5  McDonald's Jember\nTempat terfavorit saya yang...  McDonald's
# 1       5  Ini sih take away + dine in wkwk\nApalagi yg m...  McDonald's
# 2       5  McD punya tempat spesial di hati. Disini serin...  McDonald's
# 3       4  Cocok untuk sahur dan berbuka di bulan Ramadha...  McDonald's
# 4       5  Untuk rice bowl harga overprice dg porsi segit...  McDonald's
#
#            date                   date_new                 date_diff  \
# 0  5 tahun lalu 2020-02-06 14:03:11.710481 1825 days 00:00:26.370742
# 1  1 tahun lalu 2024-02-05 14:03:11.710499  365 days 00:00:26.370724
# 2  1 tahun lalu 2024-02-05 14:03:11.710502  365 days 00:00:26.370721
# 3  5 tahun lalu 2020-02-06 14:03:11.710504 1825 days 00:00:26.370719
# 4  1 tahun lalu 2024-02-05 14:03:11.710507  365 days 00:00:26.370716
#
#    days_ago    month sentiment
# 0      1825  2020-02  Positive
# 1       365  2024-02  Positive
# 2       365  2024-02  Positive
# 3      1825  2020-02  Positive
# 4       365  2024-02  Positive

# %%
def get_sentiment_long(text):
    chunks = [text[i:i+512] for i in range(0, len(text), 512)]
    results = [nlp(chunk)[0]['label'] for chunk in chunks]
    return max(set(results), key=results.count)

# %%
data_burger['sentiment'] = data_burger['snippet'].apply(get_sentiment_long)

# %%
data_burger.head()
# Out:
#    rating                                            snippet     fastfood  \
# 0       5  Suasananya enak, tempatnya bersih, lokasinya s...  Burger King
# 1       4  Rasa burgernya sangat iconic dan enak, kentang...  Burger King
# 2       5  Managernya ramah, sangat sigap membantu pengun...  Burger King
# 3       5  Pelayanan Baik. Untuk Tempat Nyaman cocok untu...  Burger King
# 4       5  selalu menjadi tujuan tiap ke roxy square\nsej...  Burger King
#
#             date                   date_new                date_diff  \
# 0   5 bulan lalu 2024-09-07 14:03:11.715313 150 days 00:00:30.343583
# 1   7 bulan lalu 2024-07-09 14:03:11.715325 210 days 00:00:30.343571
# 2   2 bulan lalu 2024-12-06 14:03:11.715328  60 days 00:00:30.343568
# 3  3 minggu lalu 2025-01-14 14:03:11.715331  21 days 00:00:30.343565
# 4   6 bulan lalu 2024-08-08 14:03:11.715346 180 days 00:00:30.343550
#
#    days_ago    month sentiment
# 0       150  2024-09  Positive
# 1       210  2024-07  Positive
# 2        60  2024-12  Positive
# 3        21  2025-01  Positive
# 4       180  2024-08  Positive

# %%
sentiment_count_kfc = data_kfc['sentiment'].value_counts().sort_index()
sentiment_count_mcd = data_mcd['sentiment'].value_counts().sort_index()
sentiment_count_burger = data_burger['sentiment'].value_counts().sort_index()

# %%
sentiment_count_kfc
# Out:
# sentiment
# Negative    230
# Neutral     118
# Positive    647
# Name: count, dtype: int64

# %%
sentiment_count_mcd
# Out:
# sentiment
# Negative    177
# Neutral     168
# Positive    652
# Name: count, dtype: int64

# %%
sentiment_count_burger
# Out:
# sentiment
# Negative     88
# Neutral      74
# Positive    831
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Pastikan kategori sama urutannya
categories = ['Negative', 'Neutral', 'Positive']
x = np.arange(len(categories))  # [0, 1, 2]

# Ambil nilai sesuai kategori (agar selaras dengan urutan 'categories')
values_kfc = [sentiment_count_kfc.get(cat, 0) for cat in categories]
values_mcd = [sentiment_count_mcd.get(cat, 0) for cat in categories]
values_burger = [sentiment_count_burger.get(cat, 0) for cat in categories]

plt.figure(figsize=(10,6))

# Buat bar chart dengan pergeseran posisi agar terlihat rapi
plt.bar(x - 0.2, values_kfc, width=0.2, label='KFC', color='orange')
plt.bar(x, values_mcd, width=0.2, label='McD', color='blue')
plt.bar(x + 0.2, values_burger, width=0.2, label='Burger King', color='green')

# Tambahkan label dan judul
plt.xlabel("Sentiment")
plt.ylabel("Jumlah Sentiment")
plt.title("Distribusi Sentimen Review Pelanggan")
plt.xticks(x, categories)  # Pastikan kategori sentimen sesuai di sumbu X
plt.legend()

# Tampilkan plot
plt.show()
